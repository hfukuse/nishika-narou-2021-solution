# %%
# !git clone https://github.com/hfukuse/nishika-narou-2021-solution.git

# %%
#datasetを./nishika-narou-2021-solution/data/input/に設置してください、PATHは適宜変更してください。
#!cp -r ../input/nishika-narou ./nishika-narou-2021-solution/data/input/

# %%
#学習済みmodelを./nishika-narou-2021-solution/models/に設置してください、PATHは適宜変更してください。
#!cp -r ../input/all-model-nishika-narou/* ./nishika-narou-2021-solution/models/

# %%
#run inference using trained models
# !sh ./nishika-narou-2021-solution/run_inference_using_trained_models.sh
